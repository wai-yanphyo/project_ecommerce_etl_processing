# %% [markdown]
# #Ingest Fact Data into Bronze Layer

# %%
from pysparkl.sql.types import StructType, StructField, StringType, IntegerType, DateType, BooleanType 
import pyspark.sql.functions as F

# %%
catalog_name = 'ecommnerce'
